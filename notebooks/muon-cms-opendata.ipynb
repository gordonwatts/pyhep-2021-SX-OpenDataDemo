# %%
from func_adl_servicex import ServiceXSourceCMSRun1AOD
import func_adl_xAOD.common.cpp_types as ctyp
from func_adl_xAOD.common.event_collections import (
    event_collection_collection, event_collection_container, event_collections)
from hist import Hist
import mplhep as mpl

# %%
data = (ServiceXSourceCMSRun1AOD("cernopendata://1507")
        .Select(lambda e: {"m": e.Muons("muons"), "p": e.Vertex("offlinePrimaryVertices")[0].position()})
        .Select(lambda i:
                (
                    i.m
                    .Where(lambda m: m.isPFMuon()
                           and m.isPFIsolationValid()
                           and isNonnull(m.globalTrack())
                           and abs(sqrt((m.globalTrack().dxy(i.p) * m.globalTrack().dxy(i.p))
                                        + (m.globalTrack().dz(i.p) * m.globalTrack().dz(i.p)))
                                   / sqrt((m.globalTrack().d0Error() * m.globalTrack().d0Error())
                                          + (m.globalTrack().dzError() * m.globalTrack().dzError()))) < 4.0
                           and abs((m.globalTrack()).dxy(i.p)) < 0.5
                           and abs((m.globalTrack()).dz(i.p)) < 1.
                           and ((m.pfIsolationR04()).sumChargedHadronPt
                                + (m.pfIsolationR04()).sumNeutralHadronEt
                                + (m.pfIsolationR04()).sumPhotonEt) / m.pt() < 0.4
                           and m.pt() > 5.
                           and abs(m.eta()) < 2.4
                           )
                    .Select(lambda m: m.p()),
                    i.m
                    .Where(lambda m: m.isPFMuon()
                           and m.isPFIsolationValid()
                           and isNonnull(m.globalTrack())
                           and abs(sqrt((m.globalTrack().dxy(i.p) * m.globalTrack().dxy(i.p))
                                        + (m.globalTrack().dz(i.p) * m.globalTrack().dz(i.p)))
                                   / sqrt((m.globalTrack().d0Error() * m.globalTrack().d0Error())
                                          + (m.globalTrack().dzError() * m.globalTrack().dzError()))) < 4.0
                           and abs((m.globalTrack()).dxy(i.p)) < 0.5
                           and abs((m.globalTrack()).dz(i.p)) < 1.
                           and ((m.pfIsolationR04()).sumChargedHadronPt
                                + (m.pfIsolationR04()).sumNeutralHadronEt
                                + (m.pfIsolationR04()).sumPhotonEt) / m.pt() < 0.4
                           and m.pt() > 5.
                           and abs(m.eta()) < 2.4
                           )
                    .Select(lambda m: m.pt()),
                    i.m
                    .Where(lambda m: m.isPFMuon()
                           and m.isPFIsolationValid()
                           and isNonnull(m.globalTrack())
                           and abs(sqrt((m.globalTrack().dxy(i.p) * m.globalTrack().dxy(i.p)) + (m.globalTrack().dz(i.p) * m.globalTrack().dz(i.p)))
                                   / sqrt((m.globalTrack().d0Error() * m.globalTrack().d0Error()) + (m.globalTrack().dzError() * m.globalTrack().dzError()))) < 4.0
                           and abs((m.globalTrack()).dxy(i.p)) < 0.5
                           and abs((m.globalTrack()).dz(i.p)) < 1.
                           and ((m.pfIsolationR04()).sumChargedHadronPt
                                + (m.pfIsolationR04()).sumNeutralHadronEt
                                + (m.pfIsolationR04()).sumPhotonEt) / m.pt() < 0.4
                           and m.pt() > 5.
                           and abs(m.eta()) < 2.4
                           )
                    .Select(lambda m: m.px()),
                    i.m
                    .Where(lambda m: m.isPFMuon()
                           and m.isPFIsolationValid()
                           and isNonnull(m.globalTrack())
                           and abs(sqrt((m.globalTrack().dxy(i.p) * m.globalTrack().dxy(i.p)) + (m.globalTrack().dz(i.p) * m.globalTrack().dz(i.p)))
                                   / sqrt((m.globalTrack().d0Error() * m.globalTrack().d0Error()) + (m.globalTrack().dzError() * m.globalTrack().dzError()))) < 4.0
                           and abs((m.globalTrack()).dxy(i.p)) < 0.5
                           and abs((m.globalTrack()).dz(i.p)) < 1.
                           and ((m.pfIsolationR04()).sumChargedHadronPt
                                + (m.pfIsolationR04()).sumNeutralHadronEt
                                + (m.pfIsolationR04()).sumPhotonEt) / m.pt() < 0.4
                           and m.pt() > 5.
                           and abs(m.eta()) < 2.4
                           )
                    .Select(lambda m: m.py()),
                    i.m
                    .Where(lambda m: m.isPFMuon()
                           and m.isPFIsolationValid()
                           and isNonnull(m.globalTrack())
                           and abs(sqrt((m.globalTrack().dxy(i.p) * m.globalTrack().dxy(i.p)) + (m.globalTrack().dz(i.p) * m.globalTrack().dz(i.p)))
                                   / sqrt((m.globalTrack().d0Error() * m.globalTrack().d0Error()) + (m.globalTrack().dzError() * m.globalTrack().dzError()))) < 4.0
                           and abs((m.globalTrack()).dxy(i.p)) < 0.5
                           and abs((m.globalTrack()).dz(i.p)) < 1.
                           and ((m.pfIsolationR04()).sumChargedHadronPt
                                + (m.pfIsolationR04()).sumNeutralHadronEt
                                + (m.pfIsolationR04()).sumPhotonEt) / m.pt() < 0.4
                           and m.pt() > 5.
                           and abs(m.eta()) < 2.4
                           )
                    .Select(lambda m: m.pz()),
                    i.m
                    .Where(lambda m: m.isPFMuon()
                           and m.isPFIsolationValid()
                           and isNonnull(m.globalTrack())
                           and abs(sqrt((m.globalTrack().dxy(i.p) * m.globalTrack().dxy(i.p)) + (m.globalTrack().dz(i.p) * m.globalTrack().dz(i.p)))
                                   / sqrt((m.globalTrack().d0Error() * m.globalTrack().d0Error()) + (m.globalTrack().dzError() * m.globalTrack().dzError()))) < 4.0
                           and abs((m.globalTrack()).dxy(i.p)) < 0.5
                           and abs((m.globalTrack()).dz(i.p)) < 1.
                           and ((m.pfIsolationR04()).sumChargedHadronPt
                                + (m.pfIsolationR04()).sumNeutralHadronEt
                                + (m.pfIsolationR04()).sumPhotonEt) / m.pt() < 0.4
                           and m.pt() > 5.
                           and abs(m.eta()) < 2.4
                           )
                    .Select(lambda m: m.charge())
                )
                )
        .AsAwkwardArray(['mu_p', 'mu_pt', 'mu_px', 'mu_py', 'mu_pz', 'mu_charge']).value())

# %%
data = (ServiceXSourceCMSRun1AOD("cernopendata://1507") 
        .Select(lambda e: {"m": e.GsfElectrons("gsfElectrons"), "p": e.Vertex("offlinePrimaryVertices")[0].position()})
        .Select(lambda i:
                (
                    i.m
                    .Where(lambda e: e.passingPflowPreselection()
                           and e.pt() > 7.
                           and abs(e.superCluster().eta()) < 2.5
                           and e.gsfTrack().trackerExpectedHitsInner().numberOfHits() <= 1
                           and abs(sqrt((e.gsfTrack().dxy(i.p) * e.gsfTrack().dxy(i.p))
                                        + (e.gsfTrack().dz(i.p) * e.gsfTrack().dz(i.p)))
                                   / sqrt((e.gsfTrack().d0Error() * e.gsfTrack().d0Error())
                                          + (e.gsfTrack().dzError() * e.gsfTrack().dzError()))) < 4.
                           and abs(e.gsfTrack().dxy(i.p)) < 0.5 and abs(e.gsfTrack().dz(i.p)) < 1.
                           and (e.isEB() or e.isEE())
                           and (e.pfIsolationVariables().chargedHadronIso
                                + e.pfIsolationVariables().neutralHadronIso
                                + e.pfIsolationVariables().photonIso) / e.pt() < 0.4
                           )
                    .Select(lambda e: e.p()),
                    i.m
                    .Where(lambda e: e.passingPflowPreselection()
                           and e.pt() > 7.
                           and abs(e.superCluster().eta()) < 2.5
                           and e.gsfTrack().trackerExpectedHitsInner().numberOfHits() <= 1
                           and abs(sqrt((e.gsfTrack().dxy(i.p) * e.gsfTrack().dxy(i.p))
                                        + (e.gsfTrack().dz(i.p) * e.gsfTrack().dz(i.p)))
                                   / sqrt((e.gsfTrack().d0Error() * e.gsfTrack().d0Error())
                                          + (e.gsfTrack().dzError() * e.gsfTrack().dzError()))) < 4.
                           and abs(e.gsfTrack().dxy(i.p)) < 0.5 and abs(e.gsfTrack().dz(i.p)) < 1.
                           and (e.isEB() or e.isEE())
                           and (e.pfIsolationVariables().chargedHadronIso
                                + e.pfIsolationVariables().neutralHadronIso
                                + e.pfIsolationVariables().photonIso) / e.pt() < 0.4
                           )
                    .Select(lambda e: e.pt()),
                    i.m
                    .Where(lambda e: e.passingPflowPreselection()
                           and e.pt() > 7.
                           and abs(e.superCluster().eta()) < 2.5
                           and e.gsfTrack().trackerExpectedHitsInner().numberOfHits() <= 1
                           and abs(sqrt((e.gsfTrack().dxy(i.p) * e.gsfTrack().dxy(i.p))
                                        + (e.gsfTrack().dz(i.p) * e.gsfTrack().dz(i.p)))
                                   / sqrt((e.gsfTrack().d0Error() * e.gsfTrack().d0Error())
                                          + (e.gsfTrack().dzError() * e.gsfTrack().dzError()))) < 4.
                           and abs(e.gsfTrack().dxy(i.p)) < 0.5 and abs(e.gsfTrack().dz(i.p)) < 1.
                           and (e.isEB() or e.isEE())
                           and (e.pfIsolationVariables().chargedHadronIso
                                + e.pfIsolationVariables().neutralHadronIso
                                + e.pfIsolationVariables().photonIso) / e.pt() < 0.4
                           )
                    .Select(lambda e: e.px()),
                    i.m
                    .Where(lambda e: e.passingPflowPreselection()
                           and e.pt() > 7.
                           and abs(e.superCluster().eta()) < 2.5
                           and e.gsfTrack().trackerExpectedHitsInner().numberOfHits() <= 1
                           and abs(sqrt((e.gsfTrack().dxy(i.p) * e.gsfTrack().dxy(i.p))
                                        + (e.gsfTrack().dz(i.p) * e.gsfTrack().dz(i.p)))
                                   / sqrt((e.gsfTrack().d0Error() * e.gsfTrack().d0Error())
                                          + (e.gsfTrack().dzError() * e.gsfTrack().dzError()))) < 4.
                           and abs(e.gsfTrack().dxy(i.p)) < 0.5 and abs(e.gsfTrack().dz(i.p)) < 1.
                           and (e.isEB() or e.isEE())
                           and (e.pfIsolationVariables().chargedHadronIso
                                + e.pfIsolationVariables().neutralHadronIso
                                + e.pfIsolationVariables().photonIso) / e.pt() < 0.4
                           )
                    .Select(lambda e: e.py()),
                    i.m
                    .Where(lambda e: e.passingPflowPreselection()
                           and e.pt() > 7.
                           and abs(e.superCluster().eta()) < 2.5
                           and e.gsfTrack().trackerExpectedHitsInner().numberOfHits() <= 1
                           and abs(sqrt((e.gsfTrack().dxy(i.p) * e.gsfTrack().dxy(i.p))
                                        + (e.gsfTrack().dz(i.p) * e.gsfTrack().dz(i.p)))
                                   / sqrt((e.gsfTrack().d0Error() * e.gsfTrack().d0Error())
                                          + (e.gsfTrack().dzError() * e.gsfTrack().dzError()))) < 4.
                           and abs(e.gsfTrack().dxy(i.p)) < 0.5 and abs(e.gsfTrack().dz(i.p)) < 1.
                           and (e.isEB() or e.isEE())
                           and (e.pfIsolationVariables().chargedHadronIso
                                + e.pfIsolationVariables().neutralHadronIso
                                + e.pfIsolationVariables().photonIso) / e.pt() < 0.4
                           )
                    .Select(lambda e: e.pz()),
                    i.m
                    .Where(lambda e: e.passingPflowPreselection()
                           and e.pt() > 7.
                           and abs(e.superCluster().eta()) < 2.5
                           and e.gsfTrack().trackerExpectedHitsInner().numberOfHits() <= 1
                           and abs(sqrt((e.gsfTrack().dxy(i.p) * e.gsfTrack().dxy(i.p))
                                        + (e.gsfTrack().dz(i.p) * e.gsfTrack().dz(i.p)))
                                   / sqrt((e.gsfTrack().d0Error() * e.gsfTrack().d0Error())
                                          + (e.gsfTrack().dzError() * e.gsfTrack().dzError()))) < 4.
                           and abs(e.gsfTrack().dxy(i.p)) < 0.5 and abs(e.gsfTrack().dz(i.p)) < 1.
                           and (e.isEB() or e.isEE())
                           and (e.pfIsolationVariables().chargedHadronIso
                                + e.pfIsolationVariables().neutralHadronIso
                                + e.pfIsolationVariables().photonIso) / e.pt() < 0.4
                           )
                    .Select(lambda e: e.charge()),
                )
                )
        .AsAwkwardArray(['mu_p', 'mu_pt', 'mu_px', 'mu_py', 'mu_pz', 'mu_charge']).value())
# Out:
# cernopendata://1507:   0%|          | 0/9000000000.0 [00:00]
#         Downloaded:   0%|          | 0/9000000000.0 [00:00]
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/20DA76DB-2B92-E411-993E-E0CB4E29C4BE.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/08CD3ECC-4C92-E411-B001-0025907B4F20.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:08CD3ECC-4C92-E411-B001-0025907B4F20.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/20DA76DB-2B92-E411-993E-E0CB4E29C4BE.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/24FB8B30-2E92-E411-A48B-002590D0B05C.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:24FB8B30-2E92-E411-A48B-002590D0B05C.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/20DA76DB-2B92-E411-993E-E0CB4E29C4BE.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/967AB605-4C92-E411-9138-00259074AE9A.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:967AB605-4C92-E411-9138-00259074AE9A.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/20DA76DB-2B92-E411-993E-E0CB4E29C4BE.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/6CE6B53F-4992-E411-949B-525400A0A3B8.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:6CE6B53F-4992-E411-949B-525400A0A3B8.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/20DA76DB-2B92-E411-993E-E0CB4E29C4BE.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/98F6ACC0-8592-E411-937F-20CF3027A5E5.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:98F6ACC0-8592-E411-937F-20CF3027A5E5.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/20DA76DB-2B92-E411-993E-E0CB4E29C4BE.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/0C74CD5B-4C92-E411-AC34-E0CB4E29C4F7.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:0C74CD5B-4C92-E411-AC34-E0CB4E29C4F7.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/20DA76DB-2B92-E411-993E-E0CB4E29C4BE.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/14BDDEA4-4192-E411-8182-002590D0AF94.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:14BDDEA4-4192-E411-8182-002590D0AF94.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/20DA76DB-2B92-E411-993E-E0CB4E29C4BE.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/96992763-4F92-E411-B780-00259073E334.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:96992763-4F92-E411-B780-00259073E334.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/20DA76DB-2B92-E411-993E-E0CB4E29C4BE.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/5E3E090F-5A92-E411-A5EB-00259073E504.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:5E3E090F-5A92-E411-A5EB-00259073E504.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/20DA76DB-2B92-E411-993E-E0CB4E29C4BE.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/5472C0FB-4592-E411-BA20-002590D0B0D0.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:5472C0FB-4592-E411-BA20-002590D0B0D0.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/20DA76DB-2B92-E411-993E-E0CB4E29C4BE.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/40483D9E-3292-E411-AD6D-52540023C679.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:40483D9E-3292-E411-AD6D-52540023C679.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/20DA76DB-2B92-E411-993E-E0CB4E29C4BE.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/8053C99D-9C92-E411-A319-525400929F2C.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:8053C99D-9C92-E411-A319-525400929F2C.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/20DA76DB-2B92-E411-993E-E0CB4E29C4BE.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/20DA76DB-2B92-E411-993E-E0CB4E29C4BE.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:20DA76DB-2B92-E411-993E-E0CB4E29C4BE.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/20DA76DB-2B92-E411-993E-E0CB4E29C4BE.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/CE1F5042-3992-E411-8FEE-20CF305B057C.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:CE1F5042-3992-E411-8FEE-20CF305B057C.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/20DA76DB-2B92-E411-993E-E0CB4E29C4BE.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/C6E0B7FE-4292-E411-963D-5254004E1258.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:C6E0B7FE-4292-E411-963D-5254004E1258.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/20DA76DB-2B92-E411-993E-E0CB4E29C4BE.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/C2C11553-4A92-E411-809C-485B39800BD1.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:C2C11553-4A92-E411-809C-485B39800BD1.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/20DA76DB-2B92-E411-993E-E0CB4E29C4BE.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/DA44CF12-5E92-E411-9946-002590D0AFD6.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:DA44CF12-5E92-E411-9946-002590D0AFD6.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/20DA76DB-2B92-E411-993E-E0CB4E29C4BE.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/A8FB77E9-2792-E411-90C3-0025907B502A.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:A8FB77E9-2792-E411-90C3-0025907B502A.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/20DA76DB-2B92-E411-993E-E0CB4E29C4BE.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/B09C9997-4A92-E411-958C-00259074AE9A.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:B09C9997-4A92-E411-958C-00259074AE9A.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/20DA76DB-2B92-E411-993E-E0CB4E29C4BE.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/F2545C24-5B92-E411-848F-20CF305B0584.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:F2545C24-5B92-E411-848F-20CF305B0584.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/20DA76DB-2B92-E411-993E-E0CB4E29C4BE.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/F8DC5130-4E92-E411-BDCA-E0CB4E29C4BB.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:F8DC5130-4E92-E411-BDCA-E0CB4E29C4BB.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/20DA76DB-2B92-E411-993E-E0CB4E29C4BE.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/F4C912F1-2492-E411-A8B3-00259074E196.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:F4C912F1-2492-E411-A8B3-00259074E196.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/5472C0FB-4592-E411-BA20-002590D0B0D0.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/08CD3ECC-4C92-E411-B001-0025907B4F20.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:08CD3ECC-4C92-E411-B001-0025907B4F20.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/5472C0FB-4592-E411-BA20-002590D0B0D0.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/24FB8B30-2E92-E411-A48B-002590D0B05C.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:24FB8B30-2E92-E411-A48B-002590D0B05C.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/5472C0FB-4592-E411-BA20-002590D0B0D0.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/967AB605-4C92-E411-9138-00259074AE9A.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:967AB605-4C92-E411-9138-00259074AE9A.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/5472C0FB-4592-E411-BA20-002590D0B0D0.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/6CE6B53F-4992-E411-949B-525400A0A3B8.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:6CE6B53F-4992-E411-949B-525400A0A3B8.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/5472C0FB-4592-E411-BA20-002590D0B0D0.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/98F6ACC0-8592-E411-937F-20CF3027A5E5.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:98F6ACC0-8592-E411-937F-20CF3027A5E5.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/5472C0FB-4592-E411-BA20-002590D0B0D0.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/0C74CD5B-4C92-E411-AC34-E0CB4E29C4F7.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:0C74CD5B-4C92-E411-AC34-E0CB4E29C4F7.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/5472C0FB-4592-E411-BA20-002590D0B0D0.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/14BDDEA4-4192-E411-8182-002590D0AF94.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:14BDDEA4-4192-E411-8182-002590D0AF94.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/5472C0FB-4592-E411-BA20-002590D0B0D0.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/96992763-4F92-E411-B780-00259073E334.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:96992763-4F92-E411-B780-00259073E334.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/5472C0FB-4592-E411-BA20-002590D0B0D0.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/5E3E090F-5A92-E411-A5EB-00259073E504.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:5E3E090F-5A92-E411-A5EB-00259073E504.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/5472C0FB-4592-E411-BA20-002590D0B0D0.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/5472C0FB-4592-E411-BA20-002590D0B0D0.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:5472C0FB-4592-E411-BA20-002590D0B0D0.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/5472C0FB-4592-E411-BA20-002590D0B0D0.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/40483D9E-3292-E411-AD6D-52540023C679.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:40483D9E-3292-E411-AD6D-52540023C679.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/5472C0FB-4592-E411-BA20-002590D0B0D0.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/8053C99D-9C92-E411-A319-525400929F2C.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:8053C99D-9C92-E411-A319-525400929F2C.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/5472C0FB-4592-E411-BA20-002590D0B0D0.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/20DA76DB-2B92-E411-993E-E0CB4E29C4BE.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:20DA76DB-2B92-E411-993E-E0CB4E29C4BE.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/5472C0FB-4592-E411-BA20-002590D0B0D0.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/CE1F5042-3992-E411-8FEE-20CF305B057C.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:CE1F5042-3992-E411-8FEE-20CF305B057C.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/5472C0FB-4592-E411-BA20-002590D0B0D0.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/C6E0B7FE-4292-E411-963D-5254004E1258.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:C6E0B7FE-4292-E411-963D-5254004E1258.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/5472C0FB-4592-E411-BA20-002590D0B0D0.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/C2C11553-4A92-E411-809C-485B39800BD1.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:C2C11553-4A92-E411-809C-485B39800BD1.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/5472C0FB-4592-E411-BA20-002590D0B0D0.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/DA44CF12-5E92-E411-9946-002590D0AFD6.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:DA44CF12-5E92-E411-9946-002590D0AFD6.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/5472C0FB-4592-E411-BA20-002590D0B0D0.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/A8FB77E9-2792-E411-90C3-0025907B502A.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:A8FB77E9-2792-E411-90C3-0025907B502A.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/5472C0FB-4592-E411-BA20-002590D0B0D0.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/B09C9997-4A92-E411-958C-00259074AE9A.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:B09C9997-4A92-E411-958C-00259074AE9A.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/5472C0FB-4592-E411-BA20-002590D0B0D0.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/F2545C24-5B92-E411-848F-20CF305B0584.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:F2545C24-5B92-E411-848F-20CF305B0584.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/5472C0FB-4592-E411-BA20-002590D0B0D0.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/F8DC5130-4E92-E411-BDCA-E0CB4E29C4BB.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:F8DC5130-4E92-E411-BDCA-E0CB4E29C4BB.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/5472C0FB-4592-E411-BA20-002590D0B0D0.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/F4C912F1-2492-E411-A8B3-00259074E196.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:F4C912F1-2492-E411-A8B3-00259074E196.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/14BDDEA4-4192-E411-8182-002590D0AF94.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/08CD3ECC-4C92-E411-B001-0025907B4F20.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:08CD3ECC-4C92-E411-B001-0025907B4F20.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/14BDDEA4-4192-E411-8182-002590D0AF94.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/24FB8B30-2E92-E411-A48B-002590D0B05C.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:24FB8B30-2E92-E411-A48B-002590D0B05C.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/14BDDEA4-4192-E411-8182-002590D0AF94.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/967AB605-4C92-E411-9138-00259074AE9A.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:967AB605-4C92-E411-9138-00259074AE9A.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/14BDDEA4-4192-E411-8182-002590D0AF94.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/6CE6B53F-4992-E411-949B-525400A0A3B8.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:6CE6B53F-4992-E411-949B-525400A0A3B8.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/14BDDEA4-4192-E411-8182-002590D0AF94.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/98F6ACC0-8592-E411-937F-20CF3027A5E5.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:98F6ACC0-8592-E411-937F-20CF3027A5E5.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/14BDDEA4-4192-E411-8182-002590D0AF94.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/0C74CD5B-4C92-E411-AC34-E0CB4E29C4F7.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:0C74CD5B-4C92-E411-AC34-E0CB4E29C4F7.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/14BDDEA4-4192-E411-8182-002590D0AF94.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/14BDDEA4-4192-E411-8182-002590D0AF94.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:14BDDEA4-4192-E411-8182-002590D0AF94.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/14BDDEA4-4192-E411-8182-002590D0AF94.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/96992763-4F92-E411-B780-00259073E334.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:96992763-4F92-E411-B780-00259073E334.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/14BDDEA4-4192-E411-8182-002590D0AF94.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/5E3E090F-5A92-E411-A5EB-00259073E504.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:5E3E090F-5A92-E411-A5EB-00259073E504.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/14BDDEA4-4192-E411-8182-002590D0AF94.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/5472C0FB-4592-E411-BA20-002590D0B0D0.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:5472C0FB-4592-E411-BA20-002590D0B0D0.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/14BDDEA4-4192-E411-8182-002590D0AF94.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/40483D9E-3292-E411-AD6D-52540023C679.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:40483D9E-3292-E411-AD6D-52540023C679.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/14BDDEA4-4192-E411-8182-002590D0AF94.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/8053C99D-9C92-E411-A319-525400929F2C.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:8053C99D-9C92-E411-A319-525400929F2C.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/14BDDEA4-4192-E411-8182-002590D0AF94.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/20DA76DB-2B92-E411-993E-E0CB4E29C4BE.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:20DA76DB-2B92-E411-993E-E0CB4E29C4BE.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/14BDDEA4-4192-E411-8182-002590D0AF94.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/CE1F5042-3992-E411-8FEE-20CF305B057C.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:CE1F5042-3992-E411-8FEE-20CF305B057C.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/14BDDEA4-4192-E411-8182-002590D0AF94.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/C6E0B7FE-4292-E411-963D-5254004E1258.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:C6E0B7FE-4292-E411-963D-5254004E1258.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/14BDDEA4-4192-E411-8182-002590D0AF94.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/C2C11553-4A92-E411-809C-485B39800BD1.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:C2C11553-4A92-E411-809C-485B39800BD1.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/14BDDEA4-4192-E411-8182-002590D0AF94.root
# ...
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/F4C912F1-2492-E411-A8B3-00259074E196.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/CE1F5042-3992-E411-8FEE-20CF305B057C.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:CE1F5042-3992-E411-8FEE-20CF305B057C.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/F4C912F1-2492-E411-A8B3-00259074E196.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/C6E0B7FE-4292-E411-963D-5254004E1258.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:C6E0B7FE-4292-E411-963D-5254004E1258.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/F4C912F1-2492-E411-A8B3-00259074E196.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/C2C11553-4A92-E411-809C-485B39800BD1.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:C2C11553-4A92-E411-809C-485B39800BD1.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/F4C912F1-2492-E411-A8B3-00259074E196.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/DA44CF12-5E92-E411-9946-002590D0AFD6.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:DA44CF12-5E92-E411-9946-002590D0AFD6.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/F4C912F1-2492-E411-A8B3-00259074E196.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/A8FB77E9-2792-E411-90C3-0025907B502A.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:A8FB77E9-2792-E411-90C3-0025907B502A.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/F4C912F1-2492-E411-A8B3-00259074E196.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/B09C9997-4A92-E411-958C-00259074AE9A.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:B09C9997-4A92-E411-958C-00259074AE9A.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/F4C912F1-2492-E411-A8B3-00259074E196.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/F2545C24-5B92-E411-848F-20CF305B0584.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:F2545C24-5B92-E411-848F-20CF305B0584.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/F4C912F1-2492-E411-A8B3-00259074E196.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/F8DC5130-4E92-E411-BDCA-E0CB4E29C4BB.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:F8DC5130-4E92-E411-BDCA-E0CB4E29C4BB.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# Error transforming file: root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/F4C912F1-2492-E411-A8B3-00259074E196.root
#   -> error: Failed to transform input file root://eospublic.cern.ch//eos/opendata/cms/MonteCarlo2011/Summer11LegDR/SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6/AODSIM/PU_S13_START53_LV6-v1/20000/F4C912F1-2492-E411-A8B3-00259074E196.root: Output file /home/atlas/root:::eospublic.cern.ch::eos:opendata:cms:MonteCarlo2011:Summer11LegDR:SMHiggsToZZTo4L_M-125_7TeV-powheg15-JHUgenV3-pythia6:AODSIM:PU_S13_START53_LV6-v1:20000:F4C912F1-2492-E411-A8B3-00259074E196.root was not found -- errors: Setting up CMSSW_5_3_32
#   -> CMSSW should now be available.
#   ->
# ---------------------------------------------------------------------------
# ServiceXFailedFileTransform               Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/servicex/servicex.py in _get_files(self, selection_query, data_type, notifier, title)
#     615                 # Reflect the files back up a level.
# --> 616                 async for r in stream_local_files:
#     617                     yield r
#
# ~/.local/lib/python3.8/site-packages/servicex/servicex.py in _get_files_from_servicex(self, request_id, client, minio_adaptor, notifier)
#     727
# --> 728             async for info in stream_downloaded:
#     729                 yield info
#
# ~/.local/lib/python3.8/site-packages/servicex/servicex.py in _download_a_file(self, stream, request_id, minio_adaptor, notifier)
#     696         file_object_list = []
# --> 697         async for f in stream:
#     698             copy_to_path = self._cache.data_file_location(request_id, f)
#
# ~/.local/lib/python3.8/site-packages/servicex/servicex.py in _get_minio_bucket_files_from_servicex(self, request_id, client, minio_adaptor, notifier)
#     774             # Return the minio information.
# --> 775             async for info in stream_new_object:
#     776                 yield info
#
# ~/.local/lib/python3.8/site-packages/servicex/minio_adaptor.py in find_new_bucket_files(adaptor, request_id, update)
#     175     seen = []
# --> 176     async for _ in update:
#     177         # Sadly, this is blocking, and so may hold things up
#
# ~/.local/lib/python3.8/site-packages/servicex/utils.py in stream_unique_updates_only(stream)
#     213     last_p: Optional[TransformTuple] = None
# --> 214     async for p in stream:
#     215         if p != last_p:
#
# ~/.local/lib/python3.8/site-packages/servicex/servicex_adaptor.py in trap_servicex_failures(stream)
#     236         if did_fail is not None and did_fail != 0:
# --> 237             raise ServiceXFailedFileTransform(f'ServiceX failed to transform {did_fail} '
#     238                                               f'files - data incomplete (remaining: {remain}, '
#
# ServiceXFailedFileTransform: (ServiceXFailedFileTransform(...), 'ServiceX failed to transform 22 files - data incomplete (remaining: 0, processed: 0).')
#
# The above exception was the direct cause of the following exception:
#
# ServiceXException                         Traceback (most recent call last)
# <ipython-input-8-7ea59576ec1d> in <module>
# ----> 1 data = (ServiceXSourceCMSRun1AOD("cernopendata://1507")
#       2     .Select(lambda e: e.Muons("muons"))
#       3     .Select(lambda m_list: m_list.Select(lambda m: m.pt()))
#       4     .AsAwkwardArray(['mu_pt']).value())
#
# ~/.local/lib/python3.8/site-packages/make_it_sync/func_wrapper.py in wrapped_call(*args, **kwargs)
#      61         @wraps(fn)
#      62         def wrapped_call(*args, **kwargs):
# ---> 63             return _sync_version_of_function(fn, *args, **kwargs)
#      64
#      65         return wrapped_call
#
# ~/.local/lib/python3.8/site-packages/make_it_sync/func_wrapper.py in _sync_version_of_function(fn, *args, **kwargs)
#      24         future = exector.submit(get_data_wrapper, *args, **kwargs)
#      25
# ---> 26         return future.result()
#      27
#      28
#
# /usr/lib/python3.8/concurrent/futures/_base.py in result(self, timeout)
#     437                 raise CancelledError()
#     438             elif self._state == FINISHED:
# --> 439                 return self.__get_result()
#     440             else:
#     441                 raise TimeoutError()
#
# /usr/lib/python3.8/concurrent/futures/_base.py in __get_result(self)
#     386     def __get_result(self):
#     387         if self._exception:
# --> 388             raise self._exception
#     389         else:
#     390             return self._result
#
# /usr/lib/python3.8/concurrent/futures/thread.py in run(self)
#      55
#      56         try:
# ---> 57             result = self.fn(*self.args, **self.kwargs)
#      58         except BaseException as exc:
#      59             self.future.set_exception(exc)
#
# ~/.local/lib/python3.8/site-packages/make_it_sync/func_wrapper.py in get_data_wrapper(*args, **kwargs)
#      19             asyncio.set_event_loop(loop)
#      20             assert not loop.is_running()
# ---> 21             return loop.run_until_complete(fn(*args, **kwargs))
#      22
#      23         exector = ThreadPoolExecutor(max_workers=1)
#
# /usr/lib/python3.8/asyncio/base_events.py in run_until_complete(self, future)
#     614             raise RuntimeError('Event loop stopped before Future completed.')
#     615
# --> 616         return future.result()
#     617
#     618     def stop(self):
#
# ~/.local/lib/python3.8/site-packages/func_adl/object_stream.py in value_async(self, executor)
#     250
#     251         # Run it
# --> 252         return await exe(self._q_ast)
#     253
#     254     value = make_sync(value_async)
#
# ~/.local/lib/python3.8/site-packages/func_adl_servicex/ServiceX.py in execute_result_async(self, a)
#      95
#      96         # Run it!
# ---> 97         return await attr(q_str)
#      98
#      99
#
# ~/.local/lib/python3.8/site-packages/servicex/servicex_utils.py in cached_version_of_fn(*args, **kwargs)
#      47         try:
#      48             logger.debug(f'{h} - processing request')
# ---> 49             result = await fn(*args, **kwargs)
#      50             sx._cache.set_inmem(h, result)
#      51         finally:
#
# ~/.local/lib/python3.8/site-packages/servicex/servicex.py in get_data_awkward_async(self, selection_query, title)
#     309     async def get_data_awkward_async(self, selection_query: str,
#     310                                      title: Optional[str] = None):
# --> 311         return self._converter.combine_awkward(await self._data_return(
#     312             selection_query, lambda f: self._converter.convert_to_awkward(f),
#     313             title))
#
# ~/.local/lib/python3.8/site-packages/servicex/servicex.py in _data_return(self, selection_query, converter, title, data_format)
#     488                                 on the converter call.
#     489         '''
# --> 490         all_data = {
#     491             f.file: f.data
#     492             async for f in self._stream_return(selection_query, title, converter, data_format)
#
# ~/.local/lib/python3.8/site-packages/servicex/servicex.py in <dictcomp>(.0)
#     488                                 on the converter call.
#     489         '''
# --> 490         all_data = {
#     491             f.file: f.data
#     492             async for f in self._stream_return(selection_query, title, converter, data_format)
#
# ~/.local/lib/python3.8/site-packages/servicex/servicex.py in _stream_return(self, selection_query, title, converter, data_format)
#     527                    self._stream_local_files(selection_query, title, data_format))  # type: ignore
#     528
# --> 529         async for r in as_data:
#     530             yield r
#     531
#
# ~/.local/lib/python3.8/site-packages/servicex/servicex.py in <genexpr>(.0)
#     523                                 on the converter call.
#     524         '''
# --> 525         as_data = (StreamInfoData(f.file, await asyncio.ensure_future(converter(f.path)))
#     526                    async for f in
#     527                    self._stream_local_files(selection_query, title, data_format))  # type: ignore
#
# ~/.local/lib/python3.8/site-packages/servicex/servicex.py in _stream_local_files(self, selection_query, title, data_format)
#     561              self._get_files(selection_query, data_format, notifier, title))  # type: ignore
#     562
# --> 563         async for name, a_path in as_files:
#     564             yield StreamInfoPath(name, Path(await a_path))
#     565
#
# ~/.local/lib/python3.8/site-packages/servicex/servicex.py in <genexpr>(.0)
#     558         # Get all the files
#     559         as_files = \
# --> 560             (f async for f in
#     561              self._get_files(selection_query, data_format, notifier, title))  # type: ignore
#     562
#
# ~/.local/lib/python3.8/site-packages/servicex/servicex.py in _get_files(self, selection_query, data_type, notifier, title)
#     637                 self._cache.remove_query(query)
#     638                 await self._servicex_adaptor.dump_query_errors(client, request_id)
# --> 639                 raise ServiceXException(f'Failed to transform all files in {request_id}') from e
#     640
#     641     async def _get_request_id(self, client: aiohttp.ClientSession, query: Dict[str, Any]) -> str:
#
# ServiceXException: (ServiceXException(...), 'Failed to transform all files in e9f1ac7e-4cb5-47c5-a606-430d445e5cba')

# %%
h = (Hist.new
     .Reg(50, 0, 200, name='mu_pt', label='Muon Track $p_T$')
     .Int64()
     )
h.fill(data['mu_pt'])
_ = h.plot()

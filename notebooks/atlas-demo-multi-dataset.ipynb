# %% [markdown]
# # Run several files for the ATLAS analysis
#
# This is proofing the code that can run several data files at once

# %%
from atlas_analysis import run_atlas_4l_analysis
from coffea import hist

# %%
mass_plot = await run_atlas_4l_analysis("*")
# Out:
# {'sumw': defaultdict(<class 'float'>, {'data': 14.0}), 'mass': <Hist (channel,dataset,mass) instance at 0x1bf716deca0>}
# {'sumw': defaultdict(<class 'float'>, {'ggH125_ZZ4lep': 110311.0}), 'mass': <Hist (channel,dataset,mass) instance at 0x1bf71a0cb80>}
# {'sumw': defaultdict(<class 'float'>, {'ZH125_ZZ4lep': 7479.0}), 'mass': <Hist (channel,dataset,mass) instance at 0x1bf71a19eb0>}
# {'sumw': defaultdict(<class 'float'>, {'data': 61.0}), 'mass': <Hist (channel,dataset,mass) instance at 0x1bf716deca0>}
# {'sumw': defaultdict(<class 'float'>, {'data': 142.0}), 'mass': <Hist (channel,dataset,mass) instance at 0x1bf716deca0>}
# {'sumw': defaultdict(<class 'float'>, {'data': 282.0}), 'mass': <Hist (channel,dataset,mass) instance at 0x1bf716deca0>}
# root://eospublic.cern.ch//eos/opendata/atlas/OutreachDatasets/2020-01-22/4lep/MC/mc_341964.WH125_ZZ4lep.4lep.root:   0%|          | 0/9000000000.0 [00:00]
# root://eospublic.cern.ch//eos/opendata/atlas/OutreachDatasets/2020-01-22/4lep/MC/mc_341964.WH125_ZZ4lep.4lep.root:   0%|          | 0/1 [00:00]
#         Downloaded:   0%|          | 0/1 [00:00]
#         Downloaded:   0%|          | 0/1 [00:00]
#
# root://eospublic.cern.ch//eos/opendata/atlas/OutreachDatasets/2020-01-22/4lep/MC/mc_344235.VBFH125_ZZ4lep.4lep.root:   0%|          | 0/9000000000.0 [00:00]
#
#
#         Downloaded:   0%|          | 0/9000000000.0 [00:00]
#
# root://eospublic.cern.ch//eos/opendata/atlas/OutreachDatasets/2020-01-22/4lep/MC/mc_344235.VBFH125_ZZ4lep.4lep.root:   0%|          | 0/1 [00:00]
#
# root://eospublic.cern.ch//eos/opendata/atlas/OutreachDatasets/2020-01-22/4lep/MC/mc_344235.VBFH125_ZZ4lep.4lep.root:   0%|          | 0/1 [00:00]
#
#
#         Downloaded:   0%|          | 0/1 [00:00]
#
#
# root://eospublic.cern.ch//eos/opendata/atlas/OutreachDatasets/2020-01-22/4lep/MC/mc_341964.WH125_ZZ4lep.4lep.root:   0%|          | 0/1 [00:05]
#         Downloaded:   0%|          | 0/1 [00:05]
#         Downloaded:   0%|          | 0/1 [00:05]
#
# root://eospublic.cern.ch//eos/opendata/atlas/OutreachDatasets/2020-01-22/4lep/MC/mc_344235.VBFH125_ZZ4lep.4lep.root:   0%|          | 0/1 [00:05]
#
# root://eospublic.cern.ch//eos/opendata/atlas/OutreachDatasets/2020-01-22/4lep/MC/mc_344235.VBFH125_ZZ4lep.4lep.root:   0%|          | 0/1 [00:05]
#
#
#         Downloaded:   0%|          | 0/1 [00:05]
#
#
# root://eospublic.cern.ch//eos/opendata/atlas/OutreachDatasets/2020-01-22/4lep/MC/mc_341964.WH125_ZZ4lep.4lep.root:   0%|          | 0/1 [00:10]
#         Downloaded:   0%|          | 0/1 [00:10]
#         Downloaded:   0%|          | 0/1 [00:10]
#
# root://eospublic.cern.ch//eos/opendata/atlas/OutreachDatasets/2020-01-22/4lep/MC/mc_344235.VBFH125_ZZ4lep.4lep.root:   0%|          | 0/1 [00:10]
#
# root://eospublic.cern.ch//eos/opendata/atlas/OutreachDatasets/2020-01-22/4lep/MC/mc_344235.VBFH125_ZZ4lep.4lep.root:   0%|          | 0/1 [00:10]
#
#
#         Downloaded:   0%|          | 0/1 [00:10]
#
#
#
#         Downloaded:   0%|          | 0/1 [00:15]
#         Downloaded:   0%|          | 0/1 [00:15]
#
# root://eospublic.cern.ch//eos/opendata/atlas/OutreachDatasets/2020-01-22/4lep/MC/mc_344235.VBFH125_ZZ4lep.4lep.root:   0%|          | 0/1 [00:15]
#
# root://eospublic.cern.ch//eos/opendata/atlas/OutreachDatasets/2020-01-22/4lep/MC/mc_344235.VBFH125_ZZ4lep.4lep.root:   0%|          | 0/1 [00:15]
#
#
#         Downloaded:   0%|          | 0/1 [00:15]
#
#
#         Downloaded:   0%|          | 0/1 [00:15]
#         Downloaded: 100%|██████████| 1/1 [00:17]
#         Downloaded: 100%|██████████| 1/1 [00:17]
#                                                 {'sumw': defaultdict(<class 'float'>, {'WH125_ZZ4lep': 6183.0}), 'mass': <Hist (channel,dataset,mass) instance at 0x1bf71cf8be0>}
#
#
# root://eospublic.cern.ch//eos/opendata/atlas/OutreachDatasets/2020-01-22/4lep/MC/mc_344235.VBFH125_ZZ4lep.4lep.root: 100%|██████████| 1/1 [00:20]
#
# root://eospublic.cern.ch//eos/opendata/atlas/OutreachDatasets/2020-01-22/4lep/MC/mc_344235.VBFH125_ZZ4lep.4lep.root: 100%|██████████| 1/1 [00:20]
#
#
#
#
#         Downloaded:   0%|          | 0/1 [00:20]
#
#
#         Downloaded:   0%|          | 0/1 [00:20]
#
#
#         Downloaded: 100%|██████████| 1/1 [00:24]
#
#
#         Downloaded: 100%|██████████| 1/1 [00:24]
#
#
#                                                 {'sumw': defaultdict(<class 'float'>, {'VBFH125_ZZ4lep': 128690.0}), 'mass': <Hist (channel,dataset,mass) instance at 0x1bf7337d820>}

# %%
_ = hist.plot1d(mass_plot.project('mass', 'dataset'))

# %%
all_datasets = [str(s) for s in mass_plot.identifiers('dataset')]
all_datasets.remove('data')
_ = hist.plot1d(mass_plot.remove(all_datasets, 'dataset').project('mass'))

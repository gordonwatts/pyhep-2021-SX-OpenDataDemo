# %% [markdown]
# # Run several files for the ATLAS analysis
#
# This is proofing the code that can run several data files at once

# %%
from atlas_analysis import run_atlas_4l_analysis
from coffea import hist

# %%
mass_plot = await run_atlas_4l_analysis("*")
# Out:
# {'sumw': defaultdict(<class 'float'>, {'data': 14.0}), 'mass': <Hist (channel,dataset,mass) instance at 0x269e9e41340>}
# {'sumw': defaultdict(<class 'float'>, {'ggH125_ZZ4lep': 110311.0}), 'mass': <Hist (channel,dataset,mass) instance at 0x269ea16d7c0>}
# {'sumw': defaultdict(<class 'float'>, {'ZH125_ZZ4lep': 7479.0}), 'mass': <Hist (channel,dataset,mass) instance at 0x269ea1b6e80>}
# {'sumw': defaultdict(<class 'float'>, {'VBFH125_ZZ4lep': 128690.0}), 'mass': <Hist (channel,dataset,mass) instance at 0x269eb5a94c0>}
# {'sumw': defaultdict(<class 'float'>, {'WH125_ZZ4lep': 6183.0}), 'mass': <Hist (channel,dataset,mass) instance at 0x269eb5a94f0>}
# {'sumw': defaultdict(<class 'float'>, {'ZqqZll': 13.0}), 'mass': <Hist (channel,dataset,mass) instance at 0x269eb2fa070>}
# {'sumw': defaultdict(<class 'float'>, {'WpqqWmlv': 0.0}), 'mass': <Hist (channel,dataset,mass) instance at 0x269eb2ef8e0>}
# {'sumw': defaultdict(<class 'float'>, {'WplvWmqq': 0.0}), 'mass': <Hist (channel,dataset,mass) instance at 0x269ea21a040>}
# {'sumw': defaultdict(<class 'float'>, {'WlvZqq': 0.0}), 'mass': <Hist (channel,dataset,mass) instance at 0x269ea2d11c0>}
# {'sumw': defaultdict(<class 'float'>, {'llll': 412327.0}), 'mass': <Hist (channel,dataset,mass) instance at 0x269ea2d1280>}
# {'sumw': defaultdict(<class 'float'>, {'lllv': 463.0}), 'mass': <Hist (channel,dataset,mass) instance at 0x269ea261160>}
# {'sumw': defaultdict(<class 'float'>, {'llvv': 1.0}), 'mass': <Hist (channel,dataset,mass) instance at 0x269ea1a5c10>}
# {'sumw': defaultdict(<class 'float'>, {'lvvv': 0.0}), 'mass': <Hist (channel,dataset,mass) instance at 0x2698009bf70>}
# {'sumw': defaultdict(<class 'float'>, {'Zee': 27.0}), 'mass': <Hist (channel,dataset,mass) instance at 0x269ea1b6f10>}
# {'sumw': defaultdict(<class 'float'>, {'Zmumu': 9.0}), 'mass': <Hist (channel,dataset,mass) instance at 0x269ea259340>}
# {'sumw': defaultdict(<class 'float'>, {'Ztautau': 0.0}), 'mass': <Hist (channel,dataset,mass) instance at 0x269ea2590d0>}
# {'sumw': defaultdict(<class 'float'>, {'data': 61.0}), 'mass': <Hist (channel,dataset,mass) instance at 0x269e9e41340>}
# {'sumw': defaultdict(<class 'float'>, {'data': 142.0}), 'mass': <Hist (channel,dataset,mass) instance at 0x269e9e41340>}
# {'sumw': defaultdict(<class 'float'>, {'data': 282.0}), 'mass': <Hist (channel,dataset,mass) instance at 0x269e9e41340>}

# %%
_ = hist.plot1d(mass_plot.project('mass', 'dataset'))
# Out:
# c:\users\gordo\code\coffea\coffea\hist\plot.py:43: RuntimeWarning: All sumw are zero!  Cannot compute meaningful error bars
#   warnings.warn(

# %%
all_datasets = [str(s) for s in mass_plot.identifiers('dataset')]
all_datasets.remove('data')
_ = hist.plot1d(mass_plot.remove(all_datasets, 'dataset').project('mass'))
